# %%
import pandas as pd

pd.read_csv (r'C:\Users\ChoudAnt\Downloads\Aggregated_Metrics_By_Country_And_Subscriber_Status.csv')
# Out:
#                                              Video Title External Video ID  \
# 0      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 1      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 2      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 3      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 4      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# ...                                                  ...               ...
# 55287                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55288                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55289                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55290                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55291                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
#
# ...

# %%
df.isnull().sum()
# Out:
# Video Title                      0
# External Video ID                0
# Video Length                     0
# Thumbnail link                   0
# Country Code                   386
# Is Subscribed                    0
# Views                            0
# Video Likes Added                0
# Video Dislikes Added             0
# Video Likes Removed              0
# User Subscriptions Added         0
# User Subscriptions Removed       0
# Average View Percentage       1438
# Average Watch Time            1438
# User Comments Added              0
# dtype: int64

# %%
df1 = df.fillna({
    
    'date_added':' 16 april 2022',
    'Video Title':"joker",
})

# %%
print(df)
# Out:
#                                              Video Title External Video ID  \
# 0      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 1      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 2      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 3      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 4      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# ...                                                  ...               ...
# 55287                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55288                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55289                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55290                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55291                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
#
# ...

# %%
df.count()
# Out:
# Video Title                   55292
# External Video ID             55292
# Video Length                  55292
# Thumbnail link                55292
# Country Code                  54906
# Is Subscribed                 55292
# Views                         55292
# Video Likes Added             55292
# Video Dislikes Added          55292
# Video Likes Removed           55292
# User Subscriptions Added      55292
# User Subscriptions Removed    55292
# Average View Percentage       53854
# Average Watch Time            53854
# User Comments Added           55292
# dtype: int64

# %%
df
# Out:
#                                              Video Title External Video ID  \
# 0      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 1      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 2      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 3      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 4      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# ...                                                  ...               ...
# 55287                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55288                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55289                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55290                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55291                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55292 entries, 0 to 55291
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Video Title                 55292 non-null  object
#  1   External Video ID           55292 non-null  object
#  2   Video Length                55292 non-null  int64
#  3   Thumbnail link              55292 non-null  object
#  4   Country Code                54906 non-null  object
#  5   Is Subscribed               55292 non-null  bool
#  6   Views                       55292 non-null  int64
#  7   Video Likes Added           55292 non-null  int64
#  8   Video Dislikes Added        55292 non-null  int64
#  9   Video Likes Removed         55292 non-null  int64
#  10  User Subscriptions Added    55292 non-null  int64
#  11  User Subscriptions Removed  55292 non-null  int64
#  12  Average View Percentage     53854 non-null  float64
# ...

# %%
df.tail()
# Out:
#                                Video Title External Video ID  Video Length  \
# 55287  #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g            53
# 55288  #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g            53
# 55289  #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g            53
# 55290  #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g            53
# 55291  #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g            53
#
#                                          Thumbnail link Country Code  \
# 55287  https://i.ytimg.com/vi/sICJ6a2wX5g/hqdefault.jpg           MM
# 55288  https://i.ytimg.com/vi/sICJ6a2wX5g/hqdefault.jpg           SA
# 55289  https://i.ytimg.com/vi/sICJ6a2wX5g/hqdefault.jpg           DZ
# 55290  https://i.ytimg.com/vi/sICJ6a2wX5g/hqdefault.jpg           MX
# 55291  https://i.ytimg.com/vi/sICJ6a2wX5g/hqdefault.jpg           SR
#
#        Is Subscribed  Views  Video Likes Added  Video Dislikes Added  \
# ...

# %%
df.head()
# Out:
#                                          Video Title External Video ID  \
# 0  🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 1  🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 2  🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 3  🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 4  🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
#
#    Video Length                                    Thumbnail link  \
# 0            59  https://i.ytimg.com/vi/OtqQYqRNDGI/hqdefault.jpg
# 1            59  https://i.ytimg.com/vi/OtqQYqRNDGI/hqdefault.jpg
# 2            59  https://i.ytimg.com/vi/OtqQYqRNDGI/hqdefault.jpg
# 3            59  https://i.ytimg.com/vi/OtqQYqRNDGI/hqdefault.jpg
# 4            59  https://i.ytimg.com/vi/OtqQYqRNDGI/hqdefault.jpg
#
#   Country Code  Is Subscribed  Views  Video Likes Added  Video Dislikes Added  \
# ...

# %%
df.describe()
# Out:
#        Video Length          Views  Video Likes Added  Video Dislikes Added  \
# count  55292.000000   55292.000000       55292.000000          55292.000000
# mean     896.678073     100.573157           4.239311              0.106055
# std      927.380801    1704.966002          65.291451              2.507351
# min       47.000000       0.000000           0.000000              0.000000
# 25%      375.000000       2.000000           0.000000              0.000000
# 50%      545.000000       7.000000           0.000000              0.000000
# 75%      934.000000      27.000000           1.000000              0.000000
# max     5029.000000  285593.000000        9165.000000            399.000000
#
#        Video Likes Removed  User Subscriptions Added  \
# count         55292.000000              55292.000000
# mean              0.175577                  2.365279
# std               3.601171                 65.889539
# min               0.000000                  0.000000
# ...

# %%
df.any()
# Out:
# Video Title                    True
# External Video ID              True
# Video Length                   True
# Thumbnail link                 True
# Country Code                   True
# Is Subscribed                  True
# Views                          True
# Video Likes Added              True
# Video Dislikes Added           True
# Video Likes Removed            True
# User Subscriptions Added       True
# User Subscriptions Removed     True
# Average View Percentage        True
# Average Watch Time             True
# User Comments Added           False
# dtype: bool

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 55287    False
# 55288    False
# 55289    False
# 55290    False
# 55291    False
# Length: 55292, dtype: bool

# %%
df.duplicated().sum
print(df)
# Out:
#                                              Video Title External Video ID  \
# 0      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 1      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 2      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 3      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 4      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# ...                                                  ...               ...
# 55287                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55288                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55289                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55290                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55291                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
#
# ...

# %%
df.dropna()
# Out:
#                                              Video Title External Video ID  \
# 0      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 1      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 2      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 3      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 4      🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# ...                                                  ...               ...
# 55287                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55288                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55289                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55290                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55291                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
#
# ...

# %%
len(df)
# Out:
# 55292

# %%
df.sample()
# Out:
#                                              Video Title External Video ID  \
# 37365  How I Got My First Data Science Internship (An...       T77uVbLhroQ
#
#        Video Length                                    Thumbnail link  \
# 37365           633  https://i.ytimg.com/vi/T77uVbLhroQ/hqdefault.jpg
#
#       Country Code  Is Subscribed  Views  Video Likes Added  \
# 37365           KW           True      7                  0
#
#        Video Dislikes Added  Video Likes Removed  User Subscriptions Added  \
# 37365                     0                    0                         0
#
#        User Subscriptions Removed  Average View Percentage  \
# 37365                           0                 0.521555
#
#        Average Watch Time  User Comments Added
# 37365          330.144429                    0
